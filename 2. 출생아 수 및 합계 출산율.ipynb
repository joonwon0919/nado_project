# %% [markdown]
# # 2. 출생아 수 및 합계출산율

# %%
import pandas as pd

# %%
df = pd.read_excel('142801_20230704174601351_excel.xlsx', skiprows=2,nrows=2, index_col=0)
df
# Out:
# C:\Users\user-pc\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#            2012     2013     2014     2015     2016     2017     2018  \
# 출생아 수   484.600  436.500  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.297    1.187    1.205    1.239    1.172    1.052    0.977
#
#            2019     2020     2021
# 출생아 수   302.700  272.300  260.600
# 합계 출산율    0.918    0.837    0.808

# %%
df.index.values
# Out:
# array(['출생아\xa0수', '합계\xa0출산율'], dtype=object)

# %%
df.rename(index={'출생아\xa0수':'출생아 수', '합계\xa0출산율':'합계 출산율'}, inplace=True)

# %%
df.index.values
# Out:
# array(['출생아 수', '합계 출산율'], dtype=object)

# %%
df.loc['출생아 수']
# Out:
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# 2021    260.6
# Name: 출생아 수, dtype: float64

# %%
df.iloc[0]
# Out:
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# 2021    260.6
# Name: 출생아 수, dtype: float64

# %%
df
# Out:
#            2012     2013     2014     2015     2016     2017     2018  \
# 출생아 수   484.600  436.500  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.297    1.187    1.205    1.239    1.172    1.052    0.977
#
#            2019     2020     2021
# 출생아 수   302.700  272.300  260.600
# 합계 출산율    0.918    0.837    0.808

# %%
df.T
# Out:
#       출생아 수  합계 출산율
# 2012  484.6   1.297
# 2013  436.5   1.187
# 2014  435.4   1.205
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.837
# 2021  260.6   0.808

# %%
df=df.T
df
# Out:
#            2012     2013     2014     2015     2016     2017     2018  \
# 출생아 수   484.600  436.500  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.297    1.187    1.205    1.239    1.172    1.052    0.977
#
#            2019     2020     2021
# 출생아 수   302.700  272.300  260.600
# 합계 출산율    0.918    0.837    0.808

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.plot(df.index,df['출생아 수'])
plt.plot(df.index,df['합계 출산율'])

# %%
fig, axs = plt.subplots(figsize=(13,5))
axs.set_ylabel('출생아수 ')
axs.set_ylim(250,700)
axs.set_yticks([300,400,500,600])
axs.bar(df.index,df['출생아 수'], color ='r')

ax2= axs.twinx()
ax2.set_ylabel('합계 출산율')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index,df['합계 출산율'], color= 'y')

# %%
fig, axs = plt.subplots(figsize=(13,5))
axs.set_ylabel('출생아수 ')
axs.set_ylim(250,700)
axs.set_yticks([300,400,500,600])
axs.bar(df.index,df['출생아 수'], color ='r')
for idx, val in enumerate(df['출생아 수']):
    axs.text(idx, val + 12, val, ha='center')
    

ax2= axs.twiny()
ax2.set_ylabel('합계 출산율')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index,df['합계 출산율'], color= 'y', marker='o', ms=15, linewidth = 5, mec='w', mew=3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '출생아 수'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
fig, axs = plt.subplots(figsize=(13,5))
fig.suptitle('출생아 수 및 합계 출산율')
axs.set_ylabel('출생아수 ')
axs.set_ylim(250,700)
axs.set_yticks([300,400,500,600])
axs.bar(df.index,df['출생아 수'], color ='r')
for idx, val in enumerate(df['출생아 수']):
    axs.text(idx, val + 12, val, ha='center')
    

ax2= axs.twinx()
ax2.set_ylabel('합계 출산율')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index,df['합계 출산율'], color= 'y', marker='o', ms=15, linewidth = 5, mec='w', mew=3)
for idx, val in enumerate(df['합계 출산율']):
    ax2.text(idx, val+0.1, val, ha= 'center')
